# %%
import pandas as pd
#from sklearn.datasets import load_iris()
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as mcolors
import seaborn as sns

# %%
df = pd.DataFrame(
    {'Group': ['A', 'B', 'C', 'D', 'E' ],
     'Value': [1, 5, 4, 3, 9]

    }
)

# %%
plt.barh(y=df.Group, width=df.Value)
# Out:
# <BarContainer object of 5 artists>

# %%
df = df.sort_values(by = ['Value'])

# %%
# Amaç yorumlamayı doğru yapabilmek , göze daha anlaşılır gelmesi, anlamlandırmayı kolaylaştırmak
plt.barh(y=df.Group,
          width=df.Value,
          color =['red', 'blue', 'green'],
          edgecolor='black'
          )
# Out:
# <BarContainer object of 5 artists>

# %%
my_plot = plt.barh(y=df.Group,
          width=df.Value,
          color =mcolors.TABLEAU_COLORS,
          edgecolor='black',
          linewidth=2
          )
plt.bar_label(container= my_plot, padding=3)
plt.show()

# %%
from matplotlib.pyplot import xlabel, ylabel, title


plt.barh(y=df.Group,
          width=df.Value,
          color =mcolors.TABLEAU_COLORS,
          edgecolor='black',
          linewidth=2,          
          
 )
# Out:
# <BarContainer object of 5 artists>

# %%
tips= sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set(style = 'darkgrid')
sns.barplot(
    x = 'total_bill',
    y = 'day',
    data = tips,
    color = 'cyan'
)
plt.figure(figsize = (20, 10))

# %%
g = sns.FacetGrid(tips, col="day", height=4, aspect=.5)
g.map(sns.barplot, "sex", "total_bill", order=["Male", "Female"])

# %%
sns.barplot(
        x="total_bill",
        y="smoker",
        hue="sex",
        data=tips,
        color="pink"
        )
plt.figure(figsize=(16, 8))
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11736\1953333789.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:pink'` for the same effect.
#
#   sns.barplot(

# %%
total = tips.groupby(['day'])['total_bill'].sum().reset_index()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11736\327737537.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   total = tips.groupby(['day'])['total_bill'].sum().reset_index()

# %%
total
# Out:
#     day  total_bill
# 0  Thur     1096.33
# 1   Fri      325.88
# 2   Sat     1778.40
# 3   Sun     1627.16

# %%
bar1 = sns.barplot(x='day', y='total_bill', data=total)

# %%
smoker = tips[tips.smoker=='Yes']

# %%
bar2 = sns.barplot(
    x ='day',
    y='total_bill',
    data=smoker,
    estimator =sum,
    errorbar=None,
)

# %%
from matplotlib import patches
bar1 = sns.barplot(x='day', y='total_bill', data=total, color= 'darkblue')
bar2 = sns.barplot(
    x ='day',
    y='total_bill',
    data=smoker,
    estimator =sum,
    errorbar=None,
)
top_bar = patches.Patch(color = 'darkblue', label = 'non-smoker')
bottom_bar = patches.Patch(color = 'lightblue', label = 'smoker')
plt.legend(handles=[top_bar, bottom_bar])
plt.show()

# %%
df_iris = sns.load_dataset('iris')

# %%
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(data=df_iris, x='sepal_length',  kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.displot(df_iris["sepal_length"])
#displot is deprecated

# %%
#Çok kümelenmiş verilerde anlamlı olmuyor. Üst üste biniyor
sns.regplot(x=df_iris['sepal_length'],
             y= df_iris['sepal_width'], 
             marker='x',
             line_kws ={
                 "color" :"red",
                 "alpha" : 0.6,
                 "lw":5
             },
             scatter_kws={
                 "color":"darkblue",
                 "s":20
             }
             )
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lmplot(
        x='sepal_length',
        y= 'sepal_width', 
        data=df_iris,
        hue="species",
        fit_reg=False
          
     )

# %%
#boxplotoutlayer mean quartile verinin dağılımıyla ilgili yorumlar yapabiliyoruz
sns.set_theme(style="darkgrid")
sns.boxplot(x=df_iris['species'], y=df_iris['sepal_length'])
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
df_iris.boxplot(column='sepal_length', by='species')
plt.show()

# %% [markdown]
# ##### column isimlerinde boşluklardan kaçının direk o column a  erişime engeller
# ##### varlık isimlerinde boşluklardan kaçının

# %%
birds_df = pd.read_csv("birds.csv")

# %%
birds_df.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# ...

# %%
birds_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                443 non-null    object
#  1   ScientificName      443 non-null    object
#  2   Category            443 non-null    object
#  3   Order               443 non-null    object
#  4   Family              443 non-null    object
#  5   Genus               443 non-null    object
#  6   ConservationStatus  443 non-null    object
#  7   MinLength           443 non-null    float64
#  8   MaxLength           443 non-null    float64
#  9   MinBodyMass         443 non-null    float64
#  10  MaxBodyMass         443 non-null    float64
#  11  MinWingspan         443 non-null    float64
#  12  MaxWingspan         443 non-null    float64
# dtypes: float64(6), object(7)
# memory usage: 45.1+ KB

# %%
plt.barh(y=birds_df.Category,
          width=birds_df.MinLength,
          color =['red', 'blue', 'green'],
          edgecolor='black'
          
          )
# Out:
# <BarContainer object of 443 artists>

# %%
total=birds_df.groupby("Family")["MinLength"].mean().reset_index()

# %%
total
# Out:
#                Family   MinLength
# 0        Accipitridae   43.400000
# 1           Alaudidae   16.000000
# 2         Alcedinidae   28.000000
# 3             Alcidae   23.500000
# 4            Anatidae   51.817778
# 5            Apodidae   13.500000
# 6            Ardeidae   57.545455
# 7       Bombycillidae   17.000000
# 8         Calcariidae   14.600000
# 9       Caprimulgidae   22.500000
# 10       Cardinalidae   15.500000
# 11        Cathartidae   59.000000
# 12         Certhiidae   12.000000
# 13       Charadriidae   18.714286
# 14         Ciconiidae   83.000000
# 15          Cinclidae   16.500000
# 16         Columbidae   28.062500
# 17           Corvidae   35.500000
# 18          Cuculidae   29.333333
# 19         Falconidae   35.666667
# 20         Fregatidae   89.000000
# 21       Fringillidae   14.538462
# 22           Gaviidae   63.250000
# 23            Gruidae  102.000000
# 24       Hirundinidae   13.957143
# 25          Icteridae   20.066667
# ...

# %%
plt.barh(y=total.Family,
          width=total.MinLength,
          color =['red', 'blue', 'green'],
          edgecolor='black'
          
          )
# Out:
# <BarContainer object of 59 artists>

# %%
total=birds_df.groupby("Order")["MinLength"].mean().reset_index()

# %%
total
# Out:
#                 Order  MinLength
# 0     Accipitriformes  43.812500
# 1        Anseriformes  51.817778
# 2         Apodiformes   9.577778
# 3    Caprimulgiformes  22.500000
# 4      Cathartiformes  59.000000
# 5     Charadriiformes  29.820513
# 6       Ciconiiformes  83.000000
# 7       Columbiformes  28.062500
# 8       Coraciiformes  28.000000
# 9        Cuculiformes  29.333333
# 10       Falconformes  35.666667
# 11        Galliformes  45.210000
# 12        Gaviiformes  63.250000
# 13         Gruiformes  37.350000
# 14      Passeriformes  15.416923
# 15     Pelecaniformes  63.588235
# 16         Piciformes  22.570833
# 17   Podicipediformes  40.166667
# 18  Procellariiformes  46.000000
# 19       Strigiformes  33.708333
# 20         Suliformes  74.333333

# %%
my_plot=plt.barh(y=total.Order,
          width=total.MinLength,
          color =['red', 'blue', 'green'],
          edgecolor='black'
          
          )
plt.bar_label(container= my_plot, padding=3)
plt.show()

# %%
birds_Anatidae = birds_df[birds_df['Family']== 'Anatidae'][['Family', 'MinLength']]

# %%
birds_Anatidae
# Out:
#       Family  MinLength
# 0   Anatidae       47.0
# 1   Anatidae       45.0
# 2   Anatidae       64.0
# 3   Anatidae       57.3
# 4   Anatidae       64.0
# 5   Anatidae       55.0
# 6   Anatidae       63.0
# 7   Anatidae       75.0
# 8   Anatidae      125.0
# 9   Anatidae      138.0
# 10  Anatidae      115.0
# 11  Anatidae       47.0
# 12  Anatidae       41.0
# 13  Anatidae       40.0
# 14  Anatidae       41.0
# 15  Anatidae       48.0
# 16  Anatidae       46.0
# 17  Anatidae       42.0
# 18  Anatidae       42.0
# 19  Anatidae       50.0
# 20  Anatidae       54.0
# 21  Anatidae       46.9
# 22  Anatidae       51.0
# 23  Anatidae       31.0
# 24  Anatidae       48.0
# 25  Anatidae       37.0
# 26  Anatidae       39.0
# 27  Anatidae       40.6
# 28  Anatidae       39.0
# 29  Anatidae       38.0
# 30  Anatidae       50.0
# 31  Anatidae       50.0
# 32  Anatidae       38.0
# 33  Anatidae       48.0
# 34  Anatidae       48.0
# 35  Anatidae       43.0
# 36  Anatidae       44.0
# ...

# %%
sns.set(style="darkgrid")
sns.histplot(data=birds_Anatidae,
             color = "red",
              x="MinLength",
                kde=True)
plt.show()

# %%
birds_df.groupby("ConservationStatus")["MaxBodyMass"].mean()
# Out:
# ConservationStatus
# CR     360.000000
# EN    4269.500000
# EX     340.000000
# LC     663.191095
# NT     497.459259
# VU     621.210000
# Name: MaxBodyMass, dtype: float64

# %%
sns.set_theme(style="darkgrid")
sns.boxplot(x=birds_df['MaxBodyMass'], 
            y=birds_df['ConservationStatus'],
            width=0.5
            
        
            )
plt.figure(figsize=(100, 20))

# %%
sns.set_theme(style="darkgrid")
sns.boxplot(x=birds_df['ConservationStatus'], 
            y=birds_df['MaxBodyMass'],
            width=0.5
            
        
            )
plt.figure(figsize=(100, 20))

# %%
birds_df['Family'].unique()
# Out:
# array(['Anatidae', 'Odontophoridae', 'Phasianidae', 'Podicipedidae',
#        'Columbidae', 'Cuculidae', 'Caprimulgidae', 'Apodidae',
#        'Trochilidae', 'Rallidae', 'Gruidae', 'Recurvirostridae',
#        'Charadriidae', 'Scolopacidae', 'Stercorariidae', 'Alcidae',
#        'Laridae', 'Gaviidae', 'Procellariidae', 'Ciconiidae',
#        'Fregatidae', 'Phalacrocoracidae', 'Pelecanidae', 'Ardeidae',
#        'Threskiornithidae', 'Cathartidae', 'Pandionidae', 'Accipitridae',
#        'Tytonidae', 'Strigidae', 'Alcedinidae', 'Picidae', 'Falconidae',
#        'Tyrannidae', 'Laniidae', 'Vireonidae', 'Corvidae', 'Alaudidae',
#        'Hirundinidae', 'Paridae', 'Sittidae', 'Certhiidae',
#        'Troglodytidae', 'Polioptilidae', 'Cinclidae', 'Regulidae',
#        'Muscicapidae', 'Turdidae', 'Mimidae', 'Sturnidae',
#        'Bombycillidae', 'Passeridae', 'Motacillidae', 'Fringillidae',
#        'Calcariidae', 'Passerellidae', 'Icteridae', 'Parulidae',
# ...

# %%
birds_pa=birds_df[birds_df['Family']== 'Paridae']

# %%
birds_pa
# Out:
#                        Name       ScientificName                 Category  \
# 290  Black-capped chickadee  Poecile atricapilla  Tits/Chickadees/Titmice
# 291        Boreal chickadee    Poecile hudsonica  Tits/Chickadees/Titmice
# 292         Tufted titmouse   Baeolophus bicolor  Tits/Chickadees/Titmice
#
#              Order   Family       Genus ConservationStatus  MinLength  \
# 290  Passeriformes  Paridae     Poecile                 LC       12.0
# 291  Passeriformes  Paridae     Poecile                 LC       13.0
# 292  Passeriformes  Paridae  Baeolophus                 LC       14.0
#
#      MaxLength  MinBodyMass  MaxBodyMass  MinWingspan  MaxWingspan
# 290       15.0          9.0         14.0         16.0         21.0
# 291       14.0         10.0         10.0         21.0         21.0
# 292       16.0         18.0         26.0         20.0         26.0

# %%
sns.regplot(
    x=birds_df['MinLength'],
    y=birds_df['MinBodyMass'],
    marker= "+",
    line_kws={
        "color":"red",
        "alpha":0.6,
        "lw":5 
    },
    scatter_kws={
        "color":"darkblue",
        "s":50
    }
    )
# Out:
# <Axes: xlabel='MinLength', ylabel='MinBodyMass'>

# %%
sns.lmplot(
        x='MinWingspan',
        y= 'MaxWingspan', 
        data=birds_df,
        hue="Order",
        fit_reg=False
          
     )

# %%
sns.lmplot(
        x='MinWingspan',
        y= 'MaxWingspan', 
        data=birds_df,
        hue="Order",
        fit_reg=False
          
     )
plt.xlim(0, 300)
# Out:
# (0.0, 300.0)

# %%
sns.lmplot(
        x='MinLength',
        y= 'MaxLength', 
        data=birds_df,
        hue="Family",
        fit_reg=True
          
     )
